# %%
import os
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] =r"/Users/tharhtet/Documents/github/ML-in-Prod-batch-3/9_Experiment_Tracking/service_acc/service_acc.json"

# %%
from google.auth import default
creds, project = default()
print("MLflow is using:", creds.service_account_email)
# Out:
# MLflow is using: mlflow-service-acc-417@strawberry-plant-ac866.iam.gserviceaccount.com

# %%
from google.cloud import storage

client = storage.Client()
bucket = client.bucket("ths_test_dvc")
blob = bucket.blob("mlflow-test-1.txt")
blob.upload_from_string("ok test")
print("✅ upload succeeded")
# Out:
# ✅ upload succeeded
