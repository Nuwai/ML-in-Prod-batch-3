# %%
# pip install --upgrade "jax[cuda11_pip]" -f https://storage.googleapis.com/jax-releases/jax_cuda_releases.html # For NVIDIA GPU
# pip install flax optax
# pip install tensorflow-datasets==4.9.3
# pip install tfds-nightly

# %%
from flax import linen as nn
import numpy as np

class SimpleCNN(nn.Module):
    @nn.compact
    def __call__(self, x):
        # First convolutional block
        x = nn.Conv(features=32, kernel_size=(3, 3))(x)
        x = nn.relu(x)
        x = nn.avg_pool(x, window_shape=(2, 2), strides=(2, 2))

        # Second convolutional block
        x = nn.Conv(features=64, kernel_size=(3, 3))(x)
        x = nn.relu(x)
        x = nn.avg_pool(x, window_shape=(2, 2), strides=(2, 2))

        # Flatten and pass to dense layers
        x = x.reshape((x.shape[0], -1)) # Flatten
        x = nn.Dense(features=256)(x)
        x = nn.relu(x)
        x = nn.Dense(features=10)(x) # 10 output classes (e.g., for MNIST)
        return x

# %%
## Create Keys for Randomness
## JAX operations are deterministic. 
# JAX need to explicitly create and pass around keys for any random operations, like weight initialization.
import jax
import jax.numpy as jnp
import optax
from flax.training import train_state


key = jax.random.PRNGKey(0)

# %%
train_dsmodel = SimpleCNN()
# Dummy input for an MNIST image (batch size 1, 28x28 pixels, 1 channel)
dummy_input = jnp.ones([1, 28, 28, 1])
params = train_dsmodel.init(key, dummy_input)['params']

# %%
# Define the optimizer
tx = optax.adam(learning_rate=1e-3)

# Create the training state
state = train_state.TrainState.create(
    apply_fn=train_dsmodel.apply,
    params=params,
    tx=tx,
)

# %%
# Just in time compilation. Compile this whole function for performance
@jax.jit 
def train_step(state, batch):
    def loss_fn(params):
        logits = state.apply_fn({'params': params}, batch['image'])
        loss = optax.softmax_cross_entropy_with_integer_labels(
            logits=logits, labels=batch['label']
        ).mean()
        return loss

    # Calculate loss and gradients
    loss, grads = jax.value_and_grad(loss_fn)(state.params)

    # Update the state 
    state = state.apply_gradients(grads=grads)
    return state, loss

# %%
@jax.jit
def eval_step(params, batch):
    """Computes accuracy for a batch."""
    logits = SimpleCNN().apply({'params': params}, batch['image'])
    accuracy = jnp.mean(jnp.argmax(logits, -1) == batch['label'])
    return accuracy

# %% [markdown]
# ### Dataset Loader and helper funcs

# %%
import tensorflow_datasets as tfds
def get_datasets():
    ds_builder = tfds.builder('mnist')
    ds_builder.download_and_prepare()
    train_ds = tfds.as_numpy(ds_builder.as_dataset(split='train', batch_size=-1))
    test_ds = tfds.as_numpy(ds_builder.as_dataset(split='test', batch_size=-1))
    
    # Normalize and add channel dimension
    train_ds['image'] = jnp.float32(train_ds['image']) / 255.
    test_ds['image'] = jnp.float32(test_ds['image']) / 255.
    return train_ds, test_ds



def create_batches(data, batch_size):
    """Yields batches of data."""
    num_samples = data['image'].shape[0]
    num_batches = num_samples // batch_size
    # Create a random permutation of indices
    perm = np.random.permutation(num_samples)
    for i in range(num_batches):
        batch_indices = perm[i * batch_size : (i + 1) * batch_size]
        yield {
            'image': data['image'][batch_indices],
            'label': data['label'][batch_indices]
        }

# %%
# Training loop
num_epochs = 10
learning_rate = 1e-3
batch_size = 128


# Load data
train_ds, test_ds = get_datasets()

# %%
import time
print("Starting JAX/Flax training...")
start_time = time.time()


for epoch in range(num_epochs):
    epoch_loss = 0.
    for batch in create_batches(train_ds, batch_size):
        state, loss = train_step(state, batch)
        # Evaluation step
        test_accuracy = eval_step(state.params, test_ds)
        print(f"Epoch {epoch + 1}, Test Accuracy: {test_accuracy * 100:.2f}%")

 # IMPORTANT: JAX is asynchronous. block_until_ready() ensures all computations are finished.
jax.block_until_ready(state) 
end_time = time.time()
print("-" * 30)
print(f"JAX/Flax Training Time: {end_time - start_time:.4f} seconds")
print("-" * 30)
# Out:
# Starting JAX/Flax training...
# Epoch 1, Test Accuracy: 26.45%
# Epoch 1, Test Accuracy: 47.54%
# Epoch 1, Test Accuracy: 46.77%
# Epoch 1, Test Accuracy: 58.24%
# Epoch 1, Test Accuracy: 67.62%
# Epoch 1, Test Accuracy: 71.54%
# Epoch 1, Test Accuracy: 72.61%
# Epoch 1, Test Accuracy: 72.47%
# Epoch 1, Test Accuracy: 77.96%
# Epoch 1, Test Accuracy: 81.49%
# Epoch 1, Test Accuracy: 79.06%
# Epoch 1, Test Accuracy: 81.12%
# Epoch 1, Test Accuracy: 81.46%
# Epoch 1, Test Accuracy: 80.49%
# Epoch 1, Test Accuracy: 81.10%
# Epoch 1, Test Accuracy: 82.37%
# Epoch 1, Test Accuracy: 82.76%
# Epoch 1, Test Accuracy: 82.91%
# Epoch 1, Test Accuracy: 84.80%
# Epoch 1, Test Accuracy: 86.59%
# Epoch 1, Test Accuracy: 86.93%
# Epoch 1, Test Accuracy: 85.02%
# Epoch 1, Test Accuracy: 82.87%
# Epoch 1, Test Accuracy: 84.23%
# Epoch 1, Test Accuracy: 85.90%
# Epoch 1, Test Accuracy: 87.33%
# Epoch 1, Test Accuracy: 88.57%
# Epoch 1, Test Accuracy: 87.74%
# Epoch 1, Test Accuracy: 85.18%
# Epoch 1, Test Accuracy: 85.05%
# Epoch 1, Test Accuracy: 87.62%
# Epoch 1, Test Accuracy: 89.08%
# Epoch 1, Test Accuracy: 88.68%
# Epoch 1, Test Accuracy: 87.95%
# Epoch 1, Test Accuracy: 88.07%
# Epoch 1, Test Accuracy: 88.20%
# Epoch 1, Test Accuracy: 88.36%
# Epoch 1, Test Accuracy: 88.22%
# Epoch 1, Test Accuracy: 88.85%
# Epoch 1, Test Accuracy: 89.32%
# Epoch 1, Test Accuracy: 89.94%
# Epoch 1, Test Accuracy: 90.14%
# Epoch 1, Test Accuracy: 90.38%
# Epoch 1, Test Accuracy: 90.39%
# Epoch 1, Test Accuracy: 90.47%
# Epoch 1, Test Accuracy: 90.67%
# Epoch 1, Test Accuracy: 91.13%
# Epoch 1, Test Accuracy: 91.41%
# Epoch 1, Test Accuracy: 91.53%
# Epoch 1, Test Accuracy: 91.51%
# Epoch 1, Test Accuracy: 91.56%
# Epoch 1, Test Accuracy: 91.66%
# Epoch 1, Test Accuracy: 91.90%
# Epoch 1, Test Accuracy: 98.21%
# Epoch 1, Test Accuracy: 98.17%
# Epoch 1, Test Accuracy: 98.13%
# Epoch 1, Test Accuracy: 98.24%
# Epoch 1, Test Accuracy: 98.28%
# Epoch 2, Test Accuracy: 98.28%
# Epoch 2, Test Accuracy: 98.29%
# Epoch 2, Test Accuracy: 98.35%
# Epoch 2, Test Accuracy: 98.35%
# Epoch 2, Test Accuracy: 98.38%
# Epoch 2, Test Accuracy: 98.42%
# Epoch 2, Test Accuracy: 98.38%
# Epoch 2, Test Accuracy: 98.41%
# Epoch 2, Test Accuracy: 98.37%
# Epoch 2, Test Accuracy: 98.40%
# Epoch 2, Test Accuracy: 98.38%
# Epoch 2, Test Accuracy: 98.30%
# Epoch 2, Test Accuracy: 98.35%
# Epoch 2, Test Accuracy: 98.34%
# Epoch 2, Test Accuracy: 98.39%
# Epoch 2, Test Accuracy: 98.41%
# Epoch 2, Test Accuracy: 98.37%
# Epoch 2, Test Accuracy: 98.33%
# Epoch 2, Test Accuracy: 98.33%
# Epoch 2, Test Accuracy: 98.28%
# Epoch 2, Test Accuracy: 98.29%
# Epoch 2, Test Accuracy: 98.31%
# Epoch 2, Test Accuracy: 98.20%
# Epoch 2, Test Accuracy: 98.19%
# Epoch 2, Test Accuracy: 98.10%
# Epoch 2, Test Accuracy: 98.08%
# Epoch 2, Test Accuracy: 98.15%
# Epoch 2, Test Accuracy: 98.19%
# Epoch 2, Test Accuracy: 98.28%
# Epoch 2, Test Accuracy: 98.42%
# Epoch 2, Test Accuracy: 98.33%
# Epoch 2, Test Accuracy: 98.11%
# Epoch 2, Test Accuracy: 98.06%
# Epoch 2, Test Accuracy: 98.04%
# Epoch 2, Test Accuracy: 97.86%
# Epoch 2, Test Accuracy: 97.80%
# Epoch 2, Test Accuracy: 97.72%
# Epoch 2, Test Accuracy: 97.80%
# Epoch 2, Test Accuracy: 97.87%
# Epoch 2, Test Accuracy: 97.94%
# Epoch 2, Test Accuracy: 97.96%
# Epoch 2, Test Accuracy: 98.05%
# Epoch 2, Test Accuracy: 98.09%
# Epoch 2, Test Accuracy: 98.13%
# Epoch 2, Test Accuracy: 98.28%
# Epoch 2, Test Accuracy: 98.31%
# Epoch 2, Test Accuracy: 98.31%
# Epoch 2, Test Accuracy: 98.29%
# Epoch 2, Test Accuracy: 98.23%
# Epoch 2, Test Accuracy: 98.13%
# Epoch 2, Test Accuracy: 98.05%
# Epoch 2, Test Accuracy: 98.11%
# Epoch 2, Test Accuracy: 98.20%
# Epoch 2, Test Accuracy: 98.25%
# Epoch 2, Test Accuracy: 98.24%
# Epoch 2, Test Accuracy: 98.22%
# Epoch 2, Test Accuracy: 98.28%
# Epoch 2, Test Accuracy: 98.31%
# Epoch 2, Test Accuracy: 98.37%
# Epoch 2, Test Accuracy: 98.44%
# Epoch 2, Test Accuracy: 98.42%
# Epoch 2, Test Accuracy: 98.40%
# Epoch 2, Test Accuracy: 98.44%
# Epoch 2, Test Accuracy: 98.41%
# Epoch 2, Test Accuracy: 98.35%
# Epoch 2, Test Accuracy: 98.35%
# Epoch 2, Test Accuracy: 98.38%
# Epoch 2, Test Accuracy: 98.33%
# Epoch 2, Test Accuracy: 98.34%
# Epoch 2, Test Accuracy: 98.35%
# Epoch 2, Test Accuracy: 98.34%
# Epoch 2, Test Accuracy: 98.37%
# Epoch 2, Test Accuracy: 98.41%
# Epoch 2, Test Accuracy: 98.37%
# Epoch 2, Test Accuracy: 98.19%
# Epoch 2, Test Accuracy: 98.10%
# Epoch 2, Test Accuracy: 97.99%
# Epoch 2, Test Accuracy: 97.84%
# Epoch 2, Test Accuracy: 97.91%
# Epoch 2, Test Accuracy: 98.04%
# Epoch 2, Test Accuracy: 98.17%
# Epoch 2, Test Accuracy: 98.26%
# Epoch 2, Test Accuracy: 98.37%
# Epoch 2, Test Accuracy: 98.37%
# Epoch 2, Test Accuracy: 98.34%
# Epoch 2, Test Accuracy: 98.35%
# Epoch 2, Test Accuracy: 98.35%
# Epoch 2, Test Accuracy: 98.39%
# Epoch 2, Test Accuracy: 98.45%
# Epoch 2, Test Accuracy: 98.40%
# Epoch 2, Test Accuracy: 98.45%
# Epoch 2, Test Accuracy: 98.43%
# Epoch 2, Test Accuracy: 98.41%
# Epoch 2, Test Accuracy: 98.35%
# Epoch 2, Test Accuracy: 98.31%
# Epoch 2, Test Accuracy: 98.30%
# Epoch 2, Test Accuracy: 98.32%
# Epoch 2, Test Accuracy: 98.37%
# Epoch 2, Test Accuracy: 98.40%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[37], line 12
#      10         # Evaluation step
#      11         test_accuracy = eval_step(state.params, test_ds)
# ---> 12         print(f"Epoch {epoch + 1}, Test Accuracy: {test_accuracy * 100:.2f}%")
#      14  # IMPORTANT: JAX is asynchronous. block_until_ready() ensures all computations are finished.
#      15 jax.block_until_ready(state)
#
# File /opt/anaconda3/envs/ths_dl/lib/python3.11/site-packages/jax/_src/array.py:342, in ArrayImpl.__format__(self, format_spec)
#     339 def __format__(self, format_spec):
#     340   # Simulates behavior of https://github.com/numpy/numpy/pull/9883
#     341   if self.ndim == 0:
# --> 342     return format(self._value[()], format_spec)
#     343   else:
#     344     return format(self._value, format_spec)
#
# File /opt/anaconda3/envs/ths_dl/lib/python3.11/site-packages/jax/_src/profiler.py:354, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     351 @wraps(func)
#     352 def wrapper(*args, **kwargs):
#     353   with TraceAnnotation(name, **decorator_kwargs):
# --> 354     return func(*args, **kwargs)
#
# File /opt/anaconda3/envs/ths_dl/lib/python3.11/site-packages/jax/_src/array.py:643, in ArrayImpl._value(self)
#     639 if self._npy_value is None:
#     640   # addressable_device_list can be empty. If it's empty, we will error below
#     641   if (self.is_fully_replicated and
#     642       self.sharding._internal_device_list.addressable_device_list):  # type: ignore
# --> 643     npy_value, did_copy = self._single_device_array_to_np_array_did_copy()
#     644     npy_value.flags.writeable = False
#     645     if did_copy:
#
# KeyboardInterrupt:
